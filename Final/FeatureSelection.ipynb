# %%
# from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = "all"

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

data=pd.read_csv("data.csv",header=0)


print "\n ################## Age ######################\n"
show_age = [sub for sub in data[data.No_show==1].Age]
no_show_age = [sub for sub in data[data.No_show==0].Age]

# plot
d = plt.hist([show_age, no_show_age], stacked=True, color=["r","b"])
for i,subd in enumerate(d[0][0]):
    print d[0][0][i]/ (d[0][1][i]+d[0][0][i])
plt.show()

print "\n ################## Interval ######################\n"
show_interval = [sub for sub in data[data.No_show==1].Interval]
no_show_interval = [sub for sub in data[data.No_show==0].Interval]
d = plt.hist([show_interval, no_show_interval], stacked=True, color=["r","b"])
for i,subd in enumerate(d[0][0]):
    print d[0][0][i]/ (d[0][1][i]+d[0][0][i])
plt.show()

print "\n ################## SMS_received ######################\n"
show_sms_recevied = [sub for sub in data[data.No_show==1].SMS_received]
# show_sms_yes_recevied = [x for x in show_sms_recevied if x == 1]
# show_sms_no_recevied = [x for x in show_sms_recevied if x == 0]
# print len(show_sms_yes_recevied)
# print len(show_sms_no_recevied)
no_show_sms_recevied = [sub for sub in data[data.No_show==0].SMS_received]
d = plt.hist([show_sms_recevied, no_show_sms_recevied], stacked=True, color=["r","b"])
for i,subd in enumerate(d[0][0]):
    print d[0][0][i]/ (d[0][1][i]+d[0][0][i])
plt.show()


print "\n ################## Gender ######################\n"
show_gender = [sub for sub in data[data.No_show==1].Gender]
no_show_gender = [sub for sub in data[data.No_show==0].Gender]
d = plt.hist([show_gender, no_show_gender], stacked=True, color=["r","b"])
# for i,subd in enumerate(d[0][0]):
#     print d[0][0][i]/ d[0][1][i]
plt.show()

print "\n ################## Scholarship ######################\n"
show_scholarship = [sub for sub in data[data.No_show==1].Scholarship]
no_show_scholarship = [sub for sub in data[data.No_show==0].Scholarship]
d = plt.hist([show_scholarship, no_show_scholarship], stacked=True, color=["r","b"])
for i,subd in enumerate(d[0][0]):
    print d[0][0][i]/ d[0][1][i]
plt.show()

print "\n ################## Hipertension ######################\n"
show_hipertension = [sub for sub in data[data.No_show==1].Hipertension]
no_show_hipertension = [sub for sub in data[data.No_show==0].Hipertension]
d = plt.hist([show_hipertension, no_show_hipertension], stacked=True, color=["r","b"])
for i,subd in enumerate(d[0][0]):
    print d[0][0][i]/ d[0][1][i]
plt.show()

print "\n ################## Diabetes ######################\n"
show_diabetes = [sub for sub in data[data.No_show==1].Diabetes]
no_show_diabetes = [sub for sub in data[data.No_show==0].Diabetes]
d = plt.hist([show_diabetes, no_show_diabetes], stacked=True, color=["r","b"])
for i,subd in enumerate(d[0][0]):
    print d[0][0][i]/ d[0][1][i]
plt.show()

print "\n ################## Alcoholism ######################\n"
show_alcoholism = [sub for sub in data[data.No_show==1].Alcoholism]
no_show_alcoholism = [sub for sub in data[data.No_show==0].Alcoholism]
d = plt.hist([show_alcoholism, no_show_alcoholism], stacked=True, color=["r","b"])
for i,subd in enumerate(d[0][0]):
    print d[0][0][i]/ d[0][1][i]
plt.show()


print "\n ################## Handcap ######################\n"
show_handcap = [sub for sub in data[data.No_show==1].Handcap]
no_show_handcap = [sub for sub in data[data.No_show==0].Handcap]
d = plt.hist([show_handcap, no_show_handcap], stacked=True, color=["r","b"])
for i,subd in enumerate(d[0][0]):
    print d[0][0][i]/ d[0][1][i]
plt.show()




# gold,chi = 400,400
# gold_height = 40+10 * np.random.randn(gold)
# chi_height = 25+6 * np.random.rand(chi)
# plt.hist([gold_height, chi_height], stacked=True, color=["r","b"])
# Out:
#  ################## Age ######################
#
# 0.173304984644
# 0.20385616402
# 0.188936129556
# 0.173391044468
# 0.152262766534
# 0.133688292147
# 0.132337102854
# 0.140306122449
# 0.146892655367
# 0.375
#  ################## Interval ######################
#
# 0.131589196124
# 0.245134383689
# 0.257311863293
# 0.231738969225
# 0.236380424746
# 0.210116731518
# 0.0571428571429
# 0.304347826087
# 0.354838709677
# 0.196428571429
#  ################## SMS_received ######################
#
# 0.143313533852
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 0.216701016918
# /Users/huangzijing/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:38: RuntimeWarning: invalid value encountered in double_scalars
#  ################## Gender ######################
#  ################## Scholarship ######################
#
# 0.198683690657
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 0.237857341105
# ...
